# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 

anime = pd.read_csv("C:\\Users\\Дарико\\Downloads\\anime.csv")
anime
# Out:
#        anime_id                                               name  \
# 0         32281                                     Kimi no Na wa.
# 1          5114                   Fullmetal Alchemist: Brotherhood
# 2         28977                                           Gintama°
# 3          9253                                        Steins;Gate
# 4          9969                                      Gintama&#039;
# ...         ...                                                ...
# 12289      9316       Toushindai My Lover: Minami tai Mecha-Minami
# 12290      5543                                        Under World
# 12291      5621                     Violence Gekiga David no Hoshi
# 12292      6133  Violence Gekiga Shin David no Hoshi: Inma Dens...
# 12293     26081                   Yasuji no Pornorama: Yacchimae!!
#
#                                                    genre   type episodes  \
# 0                   Drama, Romance, School, Supernatural  Movie        1
# ...

# %% [markdown]
# Цель: в данной практической работе необходимо использовать датасет с прошлой практической работы и визуализировать данные в виде графиков.

# %%
plt.plot(anime["episodes"].head(10), anime["anime_id"].head(10), marker="o", color="green", label="эпизод")
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# Код plt.plot(anime["episodes"].head(10), anime["anime_id"].head(10), marker="o", color="green", label="эпизод") использует данные о количестве эпизодов и идентификаторах аниме для создания линейного графика. Здесь количество эпизодов выступает в роли оси X, а идентификаторы аниме - в роли оси Y. Каждая точка на графике представляет отдельное аниме и связь между количеством эпизодов и его идентификатором.
#
# Данный график демонстрирует зависимость между количеством эпизодов и идентификаторами аниме для первых 10 записей из вашего набора данных. Он помогает визуализировать, какие идентификаторы соответствуют различному количеству эпизодов в этом ограниченном наборе данных.
#
# На первом рисунке выполняется линейный график. Зедсь выводится отношение эпизодов и ID аниме. Из графика видно что максимальное значение будет более 30000 по оси эпизодов и 1  ID аниме, а минимальное более 10 по оси эпизодов и 110 по оси ID аниме. Из этого можно сделать вывод что набольшее количество эпизодов будет у ID более 30000

# %%
plt.plot(anime["anime_id"].head(10), anime["members"].head(10), color="purple", marker="o", label="участники")
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# На данном графике представлена диаграмма участники. По результатам можно наблюдать что минимальное значение участников чуть более 15000, а максимальное значение 5000. Из этого можно сделать вывод что максимальный результат участников которые просматривают аниме 800000.Данный график демонстрирует связь между идентификаторами аниме и числом участников для первых 10 записей в вашем наборе данных. Каждая точка на графике представляет конкретное аниме и количество участников, которое оно привлекло. Присутствие линии и маркеров вместе с легендой облегчает понимание графика, а сетка помогает в оценке значений.
# Этот тип графика помогает быстро получить представление о распределении количества участников для конкретных аниме-произведений.

# %%
plt.plot(anime["anime_id"].head(20), anime["rating"].head(20), color="pink", marker="o", label="Рейтинг")
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# Данный график демонстрирует визуальную связь между идентификаторами аниме и их оценкой (рейтингом), основанной на первых 20 записях в вашем наборе данных. Каждая точка на графике представляет конкретное аниме и его рейтинг, который оно получило. Проанализировав график, можно сделать предположения об отношениях между аниме и их оценкой, а также оценить разнообразие значений рейтингов для конкретных произведений.
#
# Такой вид графика позволяет легко отслеживать различия в рейтинге аниме и выявлять возможные закономерности или аномалии. Визуализация в данном случае помогает быстро получить представление о рейтингах первых 20 аниме-произведений в вашем наборе данных.
# На этом графике изоображена диаграмма с указанием рейтингов просмотров. Исходя из этого графика можно сделать вывод что минимальным ретингом будет являтся примерно 4.15 а максимальным более 9.3.

# %%
plt.bar(anime["episodes"].head(30), anime["rating"].head(30), color = "red")

plt.xlabel('эпизод')
plt.ylabel('рейтинг')
plt.title('Столбчатая диаграмма расы')
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# Столбчатая диаграмма такой тип визуализации позволяет удобно сравнивать значения отдельных
# переменных. В столбчатой диаграмме длина столбцов пропорциональна
# показателям, которые они отображают. На данной столбчатой диаграмме представден график попуярности эпизодов и рейтинга. Исходя из данного графика видно что эпизод 1 с рейтингом почти 9 является максимальным значением, а эпизод 27 с рейтингом чкть более 8 самым минимальным.

# %%
plt.bar(anime["episodes"].head(30), anime["members"].head(30), color = "blue")

plt.xlabel('эпизод')
plt.ylabel('участники')
plt.title('Столбчатая диаграмма участников')
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# Этот вид графика позволяет быстро увидеть различия в количестве участников для разных аниме в зависимости от их количества эпизодов. Путем анализа диаграммы можно выявить соответствие между этими двумя параметрами и, возможно, обнаружить закономерности в том, как количество эпизодов влияет на количество участников.
#
# Такой вид визуализации данных помогает быстро обозначить те аниме, которые привлекают большее количество участников в зависимости от их количества эпизодов, а также сравнить этот показатель между различными произведениями. На данной столбчатой диаграмме представден график попуярности эпизодов и их росмотров. Исходя из данного графика видно что эпизод 110 и 13 и  участниками чуть менее 100000 является минимальным  значением, а эпизод 64 и участниками 800000 максимальным.

# %%
plt.bar(anime["episodes"].head(30), anime["type"].head(30), color = "gold")


plt.xlabel('эпизод')
plt.ylabel('рейтинг')
plt.title('Столбчатая диаграмма рейтинг просмотра эпизодов и тип')
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# Такой вид графика помогает визуально сравнить типы аниме в зависимости от количества эпизодов для первых 30 записей в вашем наборе данных. Путем анализа диаграммы можно увидеть, как количество эпизодов связано с типом аниме.
#
# Однако, стоит отметить, что выбор столбчатой диаграммы для отображения связи между количеством эпизодов и типом аниме может быть не самым удачным, так как тип аниме обычно не является количественной переменной, а скорее качественной. На данной столбчатой диаграмме представден график попуярности эпизодов и их типа. Исходя из данного графика видно что эпизод 1 является минимальным  значением в типе Movie, а эпизод 110 и 4 является максимальным со значением в типе OVA.

# %%
ani_count = anime['genre'].value_counts().head(30)
plt.figure(figsize=(25, 25))
plt.pie(ani_count, labels=ani_count.index, autopct='%1.1f%%', startangle=150, colors=["red", "gold", "blue", "green", "orange"])
plt.title("Жанр")
plt.show()

# %% [markdown]
# В данной диаграмме-круге представлены процентные соотношения различных жанров аниме, отображенных по их количеству в вашем наборе данных. Каждый сектор диаграммы представляет долю определенного жанра в общем объеме. Такая визуализация позволяет наглядно увидеть, какие жанры преобладают в аниме, их относительные доли и распределение в целом. Из диаграммы можно увидеть что большенство людей предпочитают смотреть hentai а наименьшее предпочитают Action, Adventure, Comedy, Shounen
#
# 1. ani_count = anime['genre'].value_counts().head(30): Этот код создает объект ani_count, который содержит подсчет количества уникальных значений в столбце 'genre' в вашем наборе данных 'anime'. Метод head(30) ограничивает список до 30 наиболее часто встречающихся жанров.
#
# 2. plt.figure(figsize=(25, 25)): Здесь создается новый график с заданным размером 25x25 дюймов.
#
# 3. plt.pie(ani_count, labels=ani_count.index, autopct='%1.1f%%', startangle=150, colors=["red", "gold", "blue", "green", "orange"]): Этот код строит "pie chart" (диаграмму-круг) на основе значений в ani_count. Каждый сектор диаграммы представляет процентное отношение каждого жанра в их общей сумме (с помощью autopct='%1.1f%%'). startangle устанавливает начальный угол для первого сектора, а colors задает цвета секторов.
#
# 4. plt.title("Жанр"): Эта строка присваивает заголовок диаграмме, указывая тему.
#
# 5. plt.show(): Эта команда выводит созданную диаграмму.
#
#
# В данной диаграмме-круге представлены процентные соотношения различных жанров аниме, отображенных по их количеству в вашем наборе данных. Каждый сектор диаграммы представляет долю определенного жанра в общем объеме. Такая визуализация позволяет наглядно увидеть, какие жанры преобладают в аниме, их относительные доли и распределение в целом.
#
# Этот вид визуализации помогает быстро получить представление о распределении жанров и их вкладе в общую картину. Очень интересно видеть, какую информацию можно извлечь из различных жанров аниме, используя диаграмму-круг

# %%
ani_count = anime['type'].value_counts()
plt.figure(figsize=(10, 8))
plt.pie(ani_count, labels=ani_count.index, autopct='%1.1f%%', startangle=150, colors=["red", "gold", "blue", "green", "orange", "Darkgrey"])
plt.title("Тип")
plt.show()

# %% [markdown]
# Код plt.pie(ani_count, labels=ani_count.index, autopct='%1.1f%%', startangle=150, colors=["red", "gold", "blue", "green", "orange", "Darkgrey"]) использует данные о количестве различных типов аниме для построения диаграммы-круга. Каждый сектор диаграммы представляет процентное отношение каждого типа аниме. Опция autopct='%1.1f%%' добавляет процентные значения на диаграмму, startangle устанавливает начальный угол для первого сектора, а colors задает цвета секторов.
#
#
#
# Данная диаграмма-круг позволяет наглядно увидеть распределение различных типов аниме в вашем наборе данных. Каждый сектор представляет процентное соотношение определенного типа аниме относительно общего числа записей. Такая визуализация помогает быстро понять, какие типы аниме преобладают и их относительные доли в наборе данных.
#
#
# В данной диаграмме-круге представлены процентные соотношения различных типов аниме, отображенных по их количеству в вашем наборе данных. Каждый сектор диаграммы представляет долю определенного жанра в общем объеме. Такая визуализация позволяет наглядно увидеть, какие жанры преобладают в аниме, их относительные доли и распределение в целом. Из диаграммы можно увидеть что большенство людей предпочитают тип TV а наименьшее предпочитают Music

# %%
plt.figure(figsize=(30, 30))
plt.scatter(anime['episodes'], anime['rating'])
plt.title('Точечная диаграмма эпизода и рейтинга') 
plt.xlabel('рейтинг')
plt.ylabel('эпизод')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
#  В данном графике я использую данные о количестве эпизодов и рейтинге для создания точечной диаграммы. Ось X показывает рейтинг, в то время как ось Y представляет количество эпизодов аниме. Каждая точка на графике представляет отдельное аниме, его количество эпизодов и полученный рейтинг. График имеет размер 30х30 дюймов, что делает его более подробным для визуального анализа.
#
# Код,  использует данные о количестве эпизодов и рейтинге для создания точечной диаграммы. Ось X показывает рейтинг, в то время как ось Y представляет количество эпизодов аниме. Каждая точка на графике представляет отдельное аниме, его количество эпизодов и полученный рейтинг. График имеет размер 30х30 дюймов, что делает его более подробным для визуального анализа.
#
# Данная точечная диаграмма отображает взаимосвязь между количеством эпизодов и рейтингом для аниме в наборе данных. Через анализ этого графика можно оценить, есть ли какая-либо зависимость между длительностью сериала и его рейтингом.
#
# Такие типы графиков обычно позволяют быстро обнаружить различия, выбросы или закономерности в данных, а также выявить связь между двумя числовыми параметрами. В данном случае она может подсказать, есть ли влияние количества эпизодов на рейтинг аниме.

# %%
plt.figure(figsize=(30, 20))
plt.scatter(anime["anime_id"], anime["rating"])
plt.title('Точечная диаграмма эпизода и рейтинга') 
plt.xlabel('рейтинг')
plt.ylabel('эпизод')
plt.grid()
plt.show()

# %% [markdown]
# В моем графике plt.scatter(anime["anime_id"], anime["rating"]) используется идентификаторы аниме и их рейтинг для создания точечной диаграммы. Ось Х показывает идентификаторы, в то время как ось Y представляет рейтинг каждого аниме.
#
# Код plt.scatter(anime["anime_id"], anime["rating"]) использует идентификаторы аниме и их рейтинг для создания точечной диаграммы. Ось Х показывает идентификаторы, в то время как ось Y представляет рейтинг каждого аниме.
#
# Данная точечная диаграмма позволяет оценить, как распределяется рейтинг относительно идентификатора для аниме в вашем датасете. Она может помочь в выявлении каких-либо паттернов или разброса значений рейтингов в зависимости от идентификатора аниме.
#
# Такие типы графиков обычно помогают быстро обозначить различия, выбросы или закономерности в данных, а также оценить связь между числовыми параметрами. В данном случае, такая визуализация поможет быстро получить представление о рейтингах для различных аниме в зависимости от их идентификаторов.

# %%
plt.figure(figsize=(10, 6))
plt.hist(anime['rating'], bins=10, color='pink', alpha=0.7, edgecolor="green")
plt.title('Гистограмма о рейтингах эпизодов')
plt.xlabel('рейтинг')
plt.ylabel('эпизод')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# Код plt.hist(anime['rating'], bins=10, color='pink', alpha=0.7, edgecolor="green") использует столбцец с рейтингами аниме для построения гистограммы. Опция bins=10 указывает, что данные будут разделены на 10 интервалов (или "корзин"). Цвет столбцов установлен на розовый (pink), с прозрачностью alpha=0.7, а цвет краев столбцов на зеленый (edgecolor="green").
#
# Данная гистограмма отображает распределение рейтингов аниме в вашем наборе данных. Она позволяет быстро понять, как часто встречаются определенные значения рейтинга и их распределение среди различных аниме-произведений.
#
# Такие гистограммы помогают выявить пики и области плотности значений, что может дать представление о типичных рейтингах для аниме. Также она может помочь в выявлении выбросов или необычных распределений в рейтингах.

# %%
plt.figure(figsize=(10, 5))
plt.hist(anime['members'], bins=10, color='orange', alpha=0.7, edgecolor="green")
plt.title('')
plt.xlabel('')
plt.ylabel('')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# Код plt.hist(anime['members'], bins=10, color='orange', alpha=0.7, edgecolor="green") использует столбец, содержащий информацию о количестве участников, для построения гистограммы. Опция bins=10 указывает на разделение данных на 10 интервалов (или "корзин"). Цвет столбцов установлен на оранжевый (orange), с прозрачностью alpha=0.7, а цвет краев столбцов - на зеленый (edgecolor="green").
#
# Данная гистограмма позволяет быстро оценить, как распределено количество участников среди различных аниме-произведений в вашем наборе данных. Она помогает увидеть, как часто встречаются разные уровни популярности среди аниме.
#
# Такие гистограммы отлично подходят для идентификации популярных и менее популярных аниме, а также для обнаружения выбросов или необычных распределений в количестве участников.

# %%
plt.figure(figsize=(10, 5))
plt.hist(anime['anime_id'], bins=10, color='blue', alpha=0.7, edgecolor="green")
plt.title('Типы аниме')
plt.xlabel('')
plt.ylabel('')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# Код plt.hist(anime['anime_id'], bins=10, color='blue', alpha=0.7, edgecolor="green") использует столбец, содержащий информацию о количестве участников, для построения гистограммы. Опция bins=10 указывает на разделение данных на 10 интервалов (или "корзин"). Цвет столбцов установлен на голубой (blue), с прозрачностью alpha=0.7, а цвет краев столбцов - на зеленый (edgecolor="green").
#
# Данная гистограмма позволяет быстро оценить, как распределено количество участников среди различных аниме-произведений в вашем наборе данных. Она помогает увидеть, как часто встречаются разные уровни популярности среди аниме.
#
# Такие гистограммы отлично подходят для идентификации популярных и менее популярных аниме, а также для обнаружения выбросов или необычных распределений в количестве участников.
#
# Исходя из моей диграммы можно сделать вывод что под максимальным значением ID будет anime_id=0 по оси х и чуть более 3000 по оси y, а минимальным 15000 по оси х и 500 по оси y

# %% [markdown]
# Вывод: в данной работе были рассмотрены разные виды графиков с данными которые я взяла из своего датасета. К каждому графику был выполнен ход работы и вывод. В работе также выполнялись такие функции как изменения цвета, разделение интервалов, прозрачность, цвет краев и разное расширение для вывода графиков.
