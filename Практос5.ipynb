# %% [markdown]
# Цель: в данной практической работе надо  реализовать базовый анализ датсета

# %%
import pandas as pd
import numpy as np

stud = pd.read_csv("C:\\Users\\Дарико\\Downloads\\StudentsPerformance.csv")
stud
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %% [markdown]
# Данной команда была создана для того чтобы вывети данные из таблицы CSV. В моем случае была таблица с данными о студентах и их данных.

# %%
stud.sort_values(by='gender')
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 563  female        group D                some college  free/reduced
# 566  female        group E           bachelor's degree  free/reduced
# 567  female        group D             master's degree  free/reduced
# 572  female        group C                some college      standard
# ..      ...            ...                         ...           ...
# 597    male        group A            some high school      standard
# 215    male        group B            some high school      standard
# 214    male        group E                 high school      standard
# 591    male        group A            some high school      standard
# 499    male        group E                some college      standard
#
#     test preparation course  math score  reading score  writing score
# ...

# %% [markdown]
# Данный метод используется для упорядочивания данных в порядке возрастания или убывания.

# %%
stud.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %% [markdown]
# Для получения первых n строк дата-сета мы будем использовать метод head(n). По умолчанию возвращается пять первых строк

# %%
stud.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race/ethnicity               1000 non-null   object
#  2   parental level of education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test preparation course      1000 non-null   object
#  5   math score                   1000 non-null   int64
#  6   reading score                1000 non-null   int64
#  7   writing score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %% [markdown]
# В данном методе мы выводим общую иноформаци о колонках, типе данных, количество использованной информации, количество не пустых значений в каждом столбце

# %%
stud.tail()
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86

# %% [markdown]
# Также используется для получения первых n строк дата-сета мы будем использовать метод head(n). По умолчанию возвращается пять первых строк.

# %%
stud.columns
# Out:
# Index(['gender', 'race/ethnicity', 'parental level of education', 'lunch',
#        'test preparation course', 'math score', 'reading score',
#        'writing score'],
#       dtype='object')

# %% [markdown]
# Данный метод columns используется в данной прроактической работе для того чтобы вывести список всех колонок

# %%
stud.to_numpy()
# Out:
# array([['female', 'group B', "bachelor's degree", ..., 72, 72, 74],
#        ['female', 'group C', 'some college', ..., 69, 90, 88],
#        ['female', 'group B', "master's degree", ..., 90, 95, 93],
#        ...,
#        ['female', 'group C', 'high school', ..., 59, 71, 65],
#        ['female', 'group D', 'some college', ..., 68, 78, 77],
#        ['female', 'group D', 'some college', ..., 77, 86, 86]],
#       dtype=object)

# %% [markdown]
# Данный метод to_numpy() используется для преобразования данных из DataFrame в массив NumPy. Этот метод возвращает представление данных DataFrame в виде массива NumPy, что может быть полезно, например, при необходимости использовать функции, специфичные для NumPy.

# %%
stud.describe()
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %% [markdown]
# Метод describe() предоставляет статистическое описание числовых данных в DataFrame. Этот метод возвращает основные статистические показатели для каждого числового столбца, такие как количество, среднее значение, стандартное отклонение, минимальное и максимальное значения, медиана и квартили.

# %%
stud.nunique()
# Out:
# gender                          2
# race/ethnicity                  5
# parental level of education     6
# lunch                           2
# test preparation course         2
# math score                     81
# reading score                  72
# writing score                  77
# dtype: int64

# %% [markdown]
# В данном методе используютеся возвращение количества уникальных значений в каждом столбце. В моем случае gender, race/ethnicity          parental level of education, lunch, test preparation course, math score, reading score, writing score

# %%
stud["math score"].unique()
# Out:
# array([ 72,  69,  90,  47,  76,  71,  88,  40,  64,  38,  58,  65,  78,
#         50,  18,  46,  54,  66,  44,  74,  73,  67,  70,  62,  63,  56,
#         97,  81,  75,  57,  55,  53,  59,  82,  77,  33,  52,   0,  79,
#         39,  45,  60,  61,  41,  49,  30,  80,  42,  27,  43,  68,  85,
#         98,  87,  51,  99,  84,  91,  83,  89,  22, 100,  96,  94,  48,
#         35,  34,  86,  92,  37,  28,  24,  26,  95,  36,  29,  32,  93,
#         19,  23,   8], dtype=int64)

# %% [markdown]
# Данный метод возвращает уникальные значения в том порядке, в котором они появляются в исходном столбце.

# %%
stud.drop_duplicates()
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %% [markdown]
# Этот метод используется для удаления дубликатов а также оставляет только первое появление каждой уникальной строки, а остальные удаляет.

# %%
subset = stud.loc[[0, 1, 2], ['gender', 'lunch', 'race/ethnicity']]
subset
# Out:
#    gender     lunch race/ethnicity
# 0  female  standard        group B
# 1  female  standard        group C
# 2  female  standard        group B

# %% [markdown]
# В данном методе используется выборка данных по строкам и столбцам с помощью loc

# %%
stud=stud.replace({"test preparation course":np.nan},"Unknown")
stud
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %% [markdown]
# Этот метод может принимать различные аргументы для определения, какие значения следует заменить, и какими значениями они должны быть
# заменены.

# %% [markdown]
# отсортировка по параметрам

# %%
stud.drop(columns= ["test preparation course"])
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#      math score  reading score  writing score
# 0            72             72             74
# ...

# %% [markdown]
# Данный метод drop используется для удаления строк или столбцов из DataFrame. Он может принимать различные параметры для определения, что именно нужно удалить.
